# %%
print(spark.version)
df = spark.read.csv("abfss://studentanalyticsplatform@onelake.dfs.fabric.microsoft.com/student_analytics_lh.Lakehouse/Files/uploads/oulad/courses.csv", header=True)
df.show()
# Out:
# StatementMeta(, 8d1406fa-7ade-4b1e-ac70-4d30b6b644c7, 3, Finished, Available, Finished, False)
# 3.5.5.5.4.20260211.1
# +-----------+-----------------+--------------------------+
# |code_module|code_presentation|module_presentation_length|
# +-----------+-----------------+--------------------------+
# |        AAA|            2013J|                       268|
# |        AAA|            2014J|                       269|
# |        BBB|            2013J|                       268|
# |        BBB|            2014J|                       262|
# |        BBB|            2013B|                       240|
# |        BBB|            2014B|                       234|
# |        CCC|            2014J|                       269|
# |        CCC|            2014B|                       241|
# |        DDD|            2013J|                       261|
# |        DDD|            2014J|                       262|
# |        DDD|            2013B|                       240|
# ...
